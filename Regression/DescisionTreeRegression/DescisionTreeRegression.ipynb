# %% [markdown]
# ###### Studied from - https://www.udemy.com/course/machinelearning/learn/lecture/5732730#overview
#
# # Decision Tree Regression
#
# Can be 2-dimensional or 3-dimensional
# (we are working with 3-d)
#
# We don't know the third dependent variable we work it off from the given 2 variables and make the decision of where the third one would be
#
# Scatter plot will split into sections, determined by the algorithm involves around the information entropy
#
# # Information Entropy -
#
# The measure of disorder.
#
# #### Range - (0 -> 1)
#
# Does a split increase our understanding of the data? if yes it adds a split or else no
# A split is also called a leaf.
#
# We have to find out the needed "leaves" of the algorithm
#
# #### Average level of information / uncertainty inherent to the variables outcomes.
#
#
# ### Not for small tables, usually used more complex datasets with many features and variables.
#
# No Feature Scaling Required.

# %% [markdown]
# #### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Importing Datasets

# %%
dataset = pd.read_csv("Position_Salaries.csv")
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# #### Training the model

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# #### Predicting Outcome

# %%
regressor.predict([[6.5]])
# Out:
# array([150000.])

# %% [markdown]
# #### Visualising the DTR

# %%
X_grid = np.arange(min(x), max(x), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(x, y, color='red')
plt.plot(X_grid, regressor.predict(X_grid), color='green')
plt.plot(x,y, color="blue")
plt.title('Truth or Bluff (Decision Tree Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# As we can see it doesn't really give usable outcomes for this small dataset
# this is mostly useful for 3-dim datasets and sets with more complex columns and data.
